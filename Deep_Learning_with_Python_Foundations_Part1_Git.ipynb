# %% [markdown]
# # **Introduction:**
#
# In this tutorial project, we are going to learn how to; Build, Plot & Define Artificial Neural Networks with Google TensorFlow. If you are new into Deep Learning, then this is highly recommended.

# %% [markdown]
# ## **Some Simple Definitions:**
#
# **1. What is Deep Learning?**
#
# The human is super with brilliant cognitive abilities, humans have a special way of learning. Also, the human brain is primarily a collection of interconnected neurons with a special way of learning. The ability of a machine to mimic this process in a complex way of some sort leads to Deep Learning.
#
#
# ---
# **Deep Learning** is a subset of machine learning that imitates the way humans learn (acquire some form of knowledge), Neural Network is synonymous with Deep Learning. Unlike traditionally algorithms which are linear in nature, Deep Learning models are quite the opposite with a form of hierarchy and complexity.
#
# ---
#
# **2. What is Neural Network?**
#
# "In 1943, neuroscientists came up with the concept of an artificial neural network as a proof-of-concept attempt to mimic how biological neurons worked. Ten years later, psychologist Frank Rosenblatt further evolved the idea by creating a single-layer neural network for supervised learning called the Perceptron.
#
# It could "learn" from good examples of data that would train the network, and then the trained network could apply that learning to new data it had never seen before." These came with limitations with non-linear functions.
#
# ---
# **Neural Networks** can be defined as a collection/aggregation of connected neurons which has the ability to transmit a signal across the network of neurons. Like the biological brain cells/neurons, they can learn, make decisions like humans.

# %% [markdown]
# **Frameworks for Deep Learning:**
#
# I am going to explore the some of them.
#
# ---
#
# To start with, **what is a** deep learning framework?
#
#
# Deep learning framework is a software package used by data science & AI researchers to design and train deep learning models. How? The concept inherent here, is to allow people train their models without having to go in depth into the algorithms underlying neural networks/deep learning.
#
# Mostly used are;   PyTorch, TensorFlow, MXNet, Keras among others.
#
# GPU-accelerated libraries such as cuDNN and NCCL can also be used to achieve high performance accelerated training.
#
#
# ---
#
# 1. Tensorflow:
#
# Developed by Google, TensorFlow’s machine learning models are easy to build, can be used for robust machine learning production, and allow powerful experimentation for research.
#
# 2. Pytorch:
#
# Facebook's PyTorch is based on Python. It is the successor of Torch, which was based on the Lua programming language. Extremely flexible for research
#
# 3. Keras:
#
# Developed by Francois Chollet, today one of the fastest growing deep learning frameworks.
#
# Keras supports high-level neural network API, written in Python. **What makes Keras interesting is that it runs on top of TensorFlow, Theano, and CNTK.**
#
# 4. Theano
#
# Developed by The University de Montreal, written in Python and centers around NVIDIA CUDA, allowing users to integrate it with GPS. The Python library allows users to define, optimise, and evaluate mathematical expressions involving multi-dimensional arrays.
#
# ---
#
# **Others include;**
#
# Deeplearning4j (DL4J), Caffe, Chainer, Microsoft CNTK

# %% [markdown]
# ## **Setup**

# %% [markdown]
# Two main libraries for building Neural Networks: TensorFlow and PyTorch. They perform similar task though Tensorflow is more production ready while PyTorch is better for building rapid prototypes being easy to learn.
#
# We are going to use;
#
# **TensorFlow and Keras**, a higher-level module way more user-friendly than pure TensorFlow and PyTorch, although a bit slower.

# %%
# !pip install tensorflow

# %% [markdown]
# To enable GPU support, check out the [official documentation](https://www.tensorflow.org/install/gpu) or [this guide](https://towardsdatascience.com/installing-tensorflow-with-cuda-cudnn-and-gpu-support-on-windows-10-60693e46e781).
#
# After setting it up, your Python instructions will be translated into **CUDA** by your machine and processed by the GPUs, for faster models running.

# %%
# !pip install shap #SHAP is a Python library that uses Shapley values to explain the output of any machine learning model.
# Out:
# ...
#      |████████████████████████████████| 564 kB 5.3 MB/s
# ...

# %%
from tensorflow.keras import models, layers, utils, backend as K #required libraries
import matplotlib.pyplot as plt #for plots
import shap

# %% [markdown]
# ### **What is ANN? Artificial Neural Network**

# %% [markdown]
# What we also know is that a Neural Network is a set of Layers composed of “neurons” (numbers) linked together by weighted links.
#
# **ANN** are usually made of layers with input, hidden and output dimensions. The output dimension is determined by the number of neurons called nodes.
#
#
# There is a computational unit that connects the weighted inputs through an activation function (which helps the neuron to switch on/off).
#
# "The weights, like in most of the machine learning algorithms, are randomly initialized and optimized during the training to minimize a loss function."
#
#
# ---
#
# **The 3 layers:**
#
# ![layer1.jfif](data:image/jpeg;base64,...)
#
#
# Source: [link](https://www.google.com/imgres?imgurl=https%3A%2F%2Fwww.researchgate.net%2Fpublication%2F321066887%2Ffigure%2Ffig1%2FAS%3A560898498625536%401510740031477%2FArtificial-neural-network-There-are-three-layers-an-input-layer-hidden-layers-and-an.png&imgrefurl=https%3A%2F%2Fwww.researchgate.net%2Ffigure%2FArtificial-neural-network-There-are-three-layers-an-input-layer-hidden-layers-and-an_fig1_321066887&tbnid=horHRdzA5Qh5BM&vet=12ahUKEwjZwNuqrPT0AhUx-YUKHeJkDAcQMygAegUIARCqAQ..i&docid=j8S-JXhjrSnlqM&w=850&h=591&itg=1&q=3%20layers%20in%20aNN&ved=2ahUKEwjZwNuqrPT0AhUx-YUKHeJkDAcQMygAegUIARCqAQ)
#
# ---
#
# ![layer2.jfif](data:image/jpeg;base64,...)
#
# Source: [Link](https://www.google.com/imgres?imgurl=https%3A%2F%2Fwww.researchgate.net%2Fpublication%2F325831461%2Ffigure%2Ffig2%2FAS%3A639036561567745%401529369597778%2FA-3-layer-neural-network-with-three-inputs-two-hidden-layers-consisting-of-four-neurons.png&imgrefurl=https%3A%2F%2Fwww.researchgate.net%2Ffigure%2FA-3-layer-neural-network-with-three-inputs-two-hidden-layers-consisting-of-four-neurons_fig2_325831461&tbnid=vI937GUOc67cwM&vet=12ahUKEwjZwNuqrPT0AhUx-YUKHeJkDAcQMygEegUIARCyAQ..i&docid=Mfr5VefytrmY5M&w=791&h=388&itg=1&q=3%20layers%20in%20aNN&ved=2ahUKEwjZwNuqrPT0AhUx-YUKHeJkDAcQMygEegUIARCyAQ)
#
#
#
# ---
#
#
# 1. Input layer: The Input Layer has as many neurons as there are inputs. For example, if the input is an image of size 28x28 (pixels), there will be 28x28 = 784 neurons in the input layer. This layer feeds the input vector to the Neural Network. Say we have a matrix of 3 features (shape N x 3), this layer takes 3 numbers as the input and passes the same 3 numbers to the next layer.
#
#
# 2. Hidden layers represent the intermediary nodes, they apply several transformations to the numbers in order to improve the accuracy of the final result, and the output is defined by the number of neurons. The Hidden Layer has an arbitrary number of neurons, determined by the scientist/developer. The number of neurons depends on the "complexity of your task ( for example, large-sized Image classification tasks requires a large number of neurons in their hidden layers)."
#
# 3. Output layer that returns the final output of the Neural Network. For a simple binary classification or regression, the output layer shall have only 1 neuron (so that it returns only 1 number). In the case of a multiclass classification with 5 different classes, the output layer shall have 5 neurons. In other words, the Output Layer has as many neurons as there are outputs required. For classification tasks, there will be as many neurons as there are classes (If there are 2 classes cats and dogs, there will be 2 neurons in the output layer).
#
#
# The simplest form of ANN is the Perceptron, a model with one layer only, very similar to the linear regression model.

# %% [markdown]
# ### **Deep Neural Networks**

# %% [markdown]
# **Deep Neural Networks**
#
# "Deep Learning models are Neural Networks but not all the Neural Networks are Deep Learning models. Generally speaking, “**Deep” Learning applies when the algorithm has at least 2 hidden layers** (so 4 layers in total including input and output)."
#
# ---
# PS: The layers can have a different number of neurons and a different activation function, and in each node, weights are trained to optimise the final result. Meaning, the more layers you add, the bigger the number of trainable parameters.
#
#
# **Things to note:**
#
# Bias, Backpropagation, Gradient Descent

# %% [markdown]
# #### **Exercise:** Let's build a Neural Network with Tensorflow using Sequential class of Keras
#
#
# **Model Design** - **Perception**
#
# This Perception model is with only one Dense layer. It feeds all its inputs to all the neurons, each neuron providing one output.
#
#
# ---

# %%
modelP = models.Sequential(name="Perceptron", layers=[
    layers.Dense(             #a fully connected layer
          name="dense",
          input_dim=3,        #with 3 features as the input
          units=1,            #and 1 node because we want 1 output
          activation='linear' #f(x)=x
    )
])
modelP.summary()
# Out:
# Model: "Perceptron"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Examining the structure and the size of the above model (in terms of parameters to train).
#
# We have 4 (3 weights and 1 bias).
#
# *To use an activation function that is not already included in Keras, like a binary step function we need to use raw TensorFlow: as shown below*

# %%
# define the function
import tensorflow as tf
def binary_step_activation(x):
    ##return 1 if x>0 else 0 
    return K.switch(x>0, tf.math.divide(x,x), tf.math.multiply(x,0))

# build the model
modelPi = models.Sequential(name="Perceptron", layers=[
      layers.Dense(             
          name="dense",
          input_dim=3,        
          units=1,            
          activation=binary_step_activation
      )
])

# %%
modelPi.summary()
# Out:
# Model: "Perceptron"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, None)              4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Model Design with Deep Neural Network Using Sequential Class**
#
# If we recall we first took a look at Perception model.

# %% [markdown]
# **Things to note when building a DNN:**
#
#
#
# *   **How many layers?:** Try different variants and see what works.  **2 Dense hidden layers** with Dropout is a good start, a technique that reduces overfitting by randomly setting inputs to 0. Hidden layers are useful to overcome the non-linearity of data, so if you don’t need non-linearity then you can avoid hidden layers. Too many hidden layers will lead to overfitting.
#
# *   **How many neurons?** "The number of hidden neurons should be between the size of the input layer and the size of the output layer. My rule of thumb is *(number of inputs + 1 output)/2*."
#
#
# *   **What activation function?** Among several types of activation functions, the most used one is *ReLU*, a piecewise linear function that returns the output only if it’s positive, and it is mainly used for hidden layers. PS: The output layer must have an activation compatible with the expected output. For example, the linear function is suited for regression problems while the *Sigmoid* is frequently used for classification.

# %% [markdown]
# In this **exercise** we assume an input **dataset of N features** and 1 binary target variable (most likely a classification use case).

# %%
n_features = 10
modeld = models.Sequential(name="DeepNN", layers=[
    ### hidden layer 1
    layers.Dense(name="h1", input_dim=n_features,
                 units=int(round((n_features+1)/2)), 
                 activation='relu'),
    layers.Dropout(name="drop1", rate=0.2),
    
    ### hidden layer 2
    layers.Dense(name="h2", units=int(round((n_features+1)/4)), 
                 activation='relu'),
    layers.Dropout(name="drop2", rate=0.2),
    
    ### layer output
    layers.Dense(name="output", units=1, activation='sigmoid')
])
modeld.summary()
# Out:
# Model: "DeepNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  h1 (Dense)                  (None, 6)                 66
#
#  drop1 (Dropout)             (None, 6)                 0
#
#  h2 (Dense)                  (None, 3)                 21
#
#  drop2 (Dropout)             (None, 3)                 0
#
#  output (Dense)              (None, 1)                 4
#
# ...
# Total params: 91
# Trainable params: 91
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The **Model class** usually offers some form of flexibility and control over the layers, and it can be used to build more complex models with multiple inputs/outputs.
#
# "Two major differences:
#
# 1. The Input layer needs to be specified while in the Sequential class it’s implied in the input dimension of the first Dense layer.
#
#
# 2. The layers are saved like objects and can be applied to the outputs of other layers like: output = layer(…)(input)"
#
# ***Let's use the Model class to build our Perceptron and DeepNN:***

# %%
# Perceptron
inputs = layers.Input(name="input", shape=(3,))
outputs = layers.Dense(name="output", units=1, 
                       activation='linear')(inputs)
modelPj = models.Model(inputs=inputs, outputs=outputs, 
                     name="Perceptron")

# DeepNN
### layer input
inputs = layers.Input(name="input", shape=(n_features,))
### hidden layer 1
h1 = layers.Dense(name="h1", units=int(round((n_features+1)/2)), activation='relu')(inputs)
h1 = layers.Dropout(name="drop1", rate=0.2)(h1)
### hidden layer 2
h2 = layers.Dense(name="h2", units=int(round((n_features+1)/4)), activation='relu')(h1)
h2 = layers.Dropout(name="drop2", rate=0.2)(h2)
### layer output
outputs = layers.Dense(name="output", units=1, activation='sigmoid')(h2)
modeldi = models.Model(inputs=inputs, outputs=outputs, name="DeepNN")

# %% [markdown]
# We can always check if the number of parameters in the model summary is the same as the one from Sequential.

# %%
modelPj.summary()
modeldi.summary()
# Out:
# Model: "Perceptron"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input (InputLayer)          [(None, 3)]               0
#
#  output (Dense)              (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# Model: "DeepNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input (InputLayer)          [(None, 10)]              0
#
#  h1 (Dense)                  (None, 6)                 66
#
#  drop1 (Dropout)             (None, 6)                 0
#
#  h2 (Dense)                  (None, 3)                 21
#
#  drop2 (Dropout)             (None, 3)                 0
#
#  output (Dense)              (None, 1)                 4
#
# ...
# Total params: 91
# Trainable params: 91
# Non-trainable params: 0
# ...

# %% [markdown]
# ## **Deep Learning Visualisation**
#
# We are going to visualise some of our exercise models above

# %% [markdown]
# **Artificial Neural Network using TensorFlow model plot**
#
# Thanks to Mauro Di Pietro

# %%
'''
Extract info for each layer in a keras model.
'''
def utils_nn_config(model):
    lst_layers = []
    if "Sequential" in str(model): #-> Sequential doesn't show the input layer
        layer = model.layers[0]
        lst_layers.append({"name":"input", "in":int(layer.input.shape[-1]), "neurons":0, 
                           "out":int(layer.input.shape[-1]), "activation":None,
                           "params":0, "bias":0})
    for layer in model.layers:
        try:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":layer.units, 
                         "out":int(layer.output.shape[-1]), "activation":layer.get_config()["activation"],
                         "params":layer.get_weights()[0], "bias":layer.get_weights()[1]}
        except:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":0, 
                         "out":int(layer.output.shape[-1]), "activation":None,
                         "params":0, "bias":0}
        lst_layers.append(dic_layer)
    return lst_layers



'''
Plot the structure of a keras neural network.
'''
def visualize_nn(model, description=False, figsize=(10,8)):
    ## get layers info
    lst_layers = utils_nn_config(model)
    layer_sizes = [layer["out"] for layer in lst_layers]
    
    ## fig setup
    fig = plt.figure(figsize=figsize)
    ax = fig.gca()
    ax.set(title=model.name)
    ax.axis('off')
    left, right, bottom, top = 0.1, 0.9, 0.1, 0.9
    x_space = (right-left) / float(len(layer_sizes)-1)
    y_space = (top-bottom) / float(max(layer_sizes))
    p = 0.025
    
    ## nodes
    for i,n in enumerate(layer_sizes):
        top_on_layer = y_space*(n-1)/2.0 + (top+bottom)/2.0
        layer = lst_layers[i]
        color = "green" if i in [0, len(layer_sizes)-1] else "blue"
        color = "red" if (layer['neurons'] == 0) and (i > 0) else color
        
        ### add description
        if (description is True):
            d = i if i == 0 else i-0.5
            if layer['activation'] is None:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
            else:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
                plt.text(x=left+d*x_space, y=top-p, fontsize=10, color=color, s=layer['activation']+" (")
                plt.text(x=left+d*x_space, y=top-2*p, fontsize=10, color=color, s="Σ"+str(layer['in'])+"[X*w]+b")
                out = " Y"  if i == len(layer_sizes)-1 else " out"
                plt.text(x=left+d*x_space, y=top-3*p, fontsize=10, color=color, s=") = "+str(layer['neurons'])+out)
        
        ### circles
        for m in range(n):
            color = "limegreen" if color == "green" else color
            circle = plt.Circle(xy=(left+i*x_space, top_on_layer-m*y_space-4*p), radius=y_space/4.0, color=color, ec='k', zorder=4)
            ax.add_artist(circle)
            
            ### add text
            if i == 0:
                plt.text(x=left-4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$X_{'+str(m+1)+'}$')
            elif i == len(layer_sizes)-1:
                plt.text(x=right+4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$y_{'+str(m+1)+'}$')
            else:
                plt.text(x=left+i*x_space+p, y=top_on_layer-m*y_space+(y_space/8.+0.01*y_space)-4*p, fontsize=10, s=r'$H_{'+str(m+1)+'}$')
    
    ## links
    for i, (n_a, n_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer = lst_layers[i+1]
        color = "green" if i == len(layer_sizes)-2 else "blue"
        color = "red" if layer['neurons'] == 0 else color
        layer_top_a = y_space*(n_a-1)/2. + (top+bottom)/2. -4*p
        layer_top_b = y_space*(n_b-1)/2. + (top+bottom)/2. -4*p
        for m in range(n_a):
            for o in range(n_b):
                line = plt.Line2D([i*x_space+left, (i+1)*x_space+left], 
                                  [layer_top_a-m*y_space, layer_top_b-o*y_space], 
                                  c=color, alpha=0.5)
                if layer['activation'] is None:
                    if o == m:
                        ax.add_artist(line)
                else:
                    ax.add_artist(line)
    plt.show()

# %% [markdown]
# We apply our defined function on the two models (Perception & ANN)

# %%
visualize_nn(modelPj, description=True, figsize=(10,8))

# %%
visualize_nn(modeldi, description=True, figsize=(10,8))

# %% [markdown]
# Using Tensorflow for plotting Model Structure

# %%
utils.plot_model(modelPj, to_file='modelPj.png', show_shapes=True, show_layer_names=True) #the perception

# %%
utils.plot_model(modeldi, to_file='modeldi.png', show_shapes=True, show_layer_names=True)

# %%
import os   #run this to delete the saved model png file on your pc which savesto your pc when you run the code in the previous cell
os.remove('modelPj.png')
os.remove('modeldi.png')

# %% [markdown]
# ### Train & Test our Deep Learning Model

# %% [markdown]
# **Steps for the Model to Run:**
#
# **Compile:** Here we define the the Optimizer, the Loss function, and the Metrics.
#
# 1. **Adam Optimiser **(a replacement optimisation algorithm for gradient descent), have used this in previous projects. When solving (binary) classification tasks, use a binary Cross-Entropy loss which compares each of the predicted probabilities to the actual class output. You can research for other ML areas.
#
# 2. **Monitoring your Metrics:** Both the Accuracy and the F1-score (it combines Precision and Recall (ensure you attempt to implement as it is not already included in TensorFlow).

# %%
# define metrics
def Recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def Precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def F1(y_true, y_pred):
    precision = Precision(y_true, y_pred)
    recall = Recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# compile the neural network
modeldi.compile(optimizer='adam', loss='binary_crossentropy', 
              metrics=['accuracy',F1])

# %% [markdown]
# **Some things to Note:**
#
# **Batches:** Sometimes, the dataset might be too large to be processed all at once, so we split into batches (the higher the batch size, the more memory space you need). Backpropagation and the consequent parameters update happen every batch.
#
# ---
#
# **Epoch:** Simply mean number of training cylcle/set. An epoch is one pass over the full training set. Say you have have 100 observations and the batch size is 20, it will take 5 batches to complete 1 epoch.
#
# PS: The **batch size should be a multiple of 2** (common: 32, 64, 128, 256) because computers usually organize the memory in power of 2.
#
# You can start with 100 epochs with a batch size of 32.
#
# ---
#
# It’s good practice to keep a portion of the data (20%-30%) for validation. "In other words, the model will set apart this fraction of data to evaluate the loss and metrics at the end of each epoch, outside the training."
#
# Let's say you got your data ready into some X and y arrays (if not you can simply generate random data using np.random

# %%
import numpy as np
X = np.random.rand(1000,10)
y = np.random.choice([1,0], size=1000)

# %%
X.shape
# Out:
# (1000, 10)

# %% [markdown]
# The Classification problem

# %%
# train/validation
training = modeldi.fit(x=X, y=y, batch_size=32, epochs=100, shuffle=True, verbose=0, validation_split=0.3)

# plot
metrics = [k for k in training.history.keys() if ("loss" not in k) and ("val" not in k)]    
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(15,3))
       
## training    
ax[0].set(title="Training")    
ax11 = ax[0].twinx()    
ax[0].plot(training.history['loss'], color='black'), ax[0].set_xlabel('Epochs'), ax[0].set_ylabel('Loss', color='black')    
for metric in metrics:        
    ax11.plot(training.history[metric], label=metric),  ax11.set_ylabel("Score", color='steelblue')    
ax11.legend()
        
## validation    
ax[1].set(title="Validation")    
ax22 = ax[1].twinx()    
ax[1].plot(training.history['val_loss'], color='black'), ax[1].set_xlabel('Epochs'), ax[1].set_ylabel('Loss', color='black')    
for metric in metrics:          
    ax22.plot(training.history['val_'+metric], label=metric), ax22.set_ylabel("Score", color="steelblue")    
plt.show()

# %% [markdown]
# Say we have a **regression problem**, we could set's the MAE as the loss and the R-squared as the metric as shown below

# %%
# define metrics #am not running this cell, 
#def R2(y, y_hat):
    ss_res =  K.sum(K.square(y - y_hat)) 
    ss_tot = K.sum(K.square(y - K.mean(y))) 
    return ( 1 - ss_res/(ss_tot + K.epsilon()) )

# compile the neural network
modeldi.compile(optimizer='adam', loss='mean_absolute_error', 
              metrics=[R2])

# %% [markdown]
# ## **Let's Explain our DL Model**
#
# Here's a good [resource link ](https://github.com/slundberg/shap#deep-learning-example-with-deepexplainer-tensorflowkeras-models) on how to use SHAP explainer for your Machine Learning models

# %% [markdown]
# References:
#
# https://www.techtarget.com/searchenterpriseai/feature/How-neural-network-training-methods-are-modeled-after-the-human-brain
#
# ---
# https://www.kdnuggets.com/2021/09/a-breakdown-deep-learning-frameworks.html
#
# ---
#
# https://www.simplilearn.com/tutorials/deep-learning-tutorial/deep-learning-frameworks
#
#
# ---
#
# https://www.freecodecamp.org/news/building-a-3-layer-neural-network-from-scratch-99239c4af5d3/
#
#
# ---
#
# https://medium.com/swlh/mathematics-behind-basic-feed-forward-neural-network-3-layers-python-from-scratch-df88085c8049
#
#
# ---
#
# https://towardsdatascience.com/deep-learning-with-python-neural-networks-complete-tutorial-6b53c0b06af0
#
#
# ---
